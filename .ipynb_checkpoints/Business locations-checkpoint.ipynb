# %%
import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt
from utilities import Geometry

# %%
fname = 'Map_of_Registered_Business_Locations.csv'
data = pd.read_csv(fname)

# %%
data.head()
# Out:
#       Location Id  Business Account Number  \
# 0  0376718-03-001                   376718
# 1  1045798-12-151                  1021444
# 2  1170655-12-171                  1080758
# 3  0439260-05-001                   439260
# 4  1172877-12-171                  1081158
#
#                         Ownership Name                             DBA Name  \
# 0                         Chan Renee W         Blossoming Lotus Acupuncture
# 1                     Benhammou Ahmida        Zaalouk Market & Deli Grocery
# 2  San Francisco Security Services Llc  San Francisco Security Services Llc
# 3                       Tyrala Glenn D         San Francisco Victorian Door
# 4                   Three R Properties                   Three R Properties
#
#              Street Address           City State  Source Zipcode  \
# 0     2670 Leavenworth St A  San Francisco    CA         94109.0
# 1            1209 Sutter St  San Francisco    CA         94109.0
# ...

# %%
data2 = data.loc[(data['City'] == 'San Francisco') & data['Business End Date'].isnull() & data['Location End Date'].isnull() & ((data['NAICS Code Description'] == 'Accommodations') | (data['NAICS Code Description'] == 'Food Services'))][['Street Address', 'Source Zipcode']].values

# %%
data2.shape
# Out:
# (10230, 2)

# %%
data2 = data2[:100]

# %%
url = 'https://maps.googleapis.com/maps/api/geocode/json?address=%s,%s&key=AIzaSyAJ4HW37Q9ip-SGiEXfsk6eTRNm3DQGY0c'
locations = [requests.get(url%(street, int(zipcode))).json()['results'][0]['geometry']['location'].values() for street, zipcode in data2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-106-6590cba641f8> in <module>()
#       1 url = 'https://maps.googleapis.com/maps/api/geocode/json?address=%s,%s&key=AIzaSyAJ4HW37Q9ip-SGiEXfsk6eTRNm3DQGY0c'
# ----> 2 locations = [requests.get(url%(street, int(zipcode))).json()['results'][0]['geometry']['location'].values() for street, zipcode in data2]
#
# IndexError: list index out of range

# %%
locations
# Out:
# [[37.7583616, -122.4367916],
#  [37.7658084, -122.4521408],
#  [37.7843318, -122.4033663],
#  [37.7735235, -122.4304669],
#  [37.7566581, -122.4216522],
#  [37.7434439, -122.4336079],
#  [37.7710486, -122.4447997],
#  [37.7845459, -122.4132313],
#  [37.7771722, -122.412601],
#  [37.7183293, -122.4489255],
#  [37.7647687, -122.4223512],
#  [37.7828176, -122.462536],
#  [37.764317, -122.4730945],
#  [37.7795147, -122.4350677],
#  [37.7572002, -122.4118053],
#  [37.7830748, -122.4206163],
#  [37.778489, -122.442649],
#  [37.7431924, -122.4325793],
#  [37.7589959, -122.4289848],
#  [37.7768403, -122.397702],
#  [37.76956759999999, -122.4226379],
#  [37.7568585, -122.410203],
#  [37.780055, -122.4064418],
#  [37.7845584, -122.3985641],
#  [37.7762372, -122.4220764],
#  [37.7880302, -122.4026327],
#  [37.7428181, -122.4783734],
#  [37.7925318, -122.3988929],
#  [37.7910575, -122.4425437],
#  [37.7087984, -122.4624475],
#  [37.7314127, -122.4378547],
#  [37.75526199999999, -122.4121718],
# ...

# %%
loc = np.array(locations)

# %%
geom = Geometry()
SF_boundaries_x, SF_boundaries_y = geom.GetSFBoundaries()

# %%
fig = plt.figure(figsize=(6,6))
h = plt.hist2d(loc[:,1], loc[:,0], bins=(100,100),range=[[-122.53,-122.35],[37.7,37.83]])
plt.plot(SF_boundaries_x, SF_boundaries_y, color='red')
